# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# Задание:
# 1. Выберите область знаний, в которой вы разбираетесь. Она должна содержать не менее 30 сущностей.
# 2. Составьте для нее онтологию любым из предложенных инструментов. (подсказка - это похоже на создание специфической базы данных).
#
# 2.1. Количество классов – не менее 5.
#
# 2.2. Обязательное использование не менее двух базовых онтологий (общеупотребимых префиксов), например foaf, geo, dc, rdf, rdfs и тд. Справочник префиксов доступен по ссылке: http://prefix.cc/
#
# 2.3. Постарайтесь использовать разные отношения (симметричные-транзитивные-инверсные...)
#
# 3. Визуализируйте получившийся граф.

# %% [markdown]
# ### 1. Выберите область знаний, в которой вы разбираетесь. Она должна содержать не менее 30 сущностей.

# %% [markdown]
# 1. верхние ноты
# 2. ноты сердца
# 3. шлейфовые ноты
# 4. освежающая вода
# 5. одеколон
# 6. туалетная вода
# 7. парфюмированная вода
# 8. духи
# 9. стойкость
# 10. группа восточных
# 11. группа древесных
# 12. группа свежих
# 13. группа цветочных
# 14. аккорд - один аккорд составляют от трех до четырех различных нот
# 15. аттар - духи с масляной основой
# 16. компот - легкий аромат, основу которого чаще всего составляют фруктовые и цветочные ноты.
# 17. ниша
# 18. селектив
# 19. конкрет - полутвердый и твердый продукт
# 20. блоттер - бумажка
# 23. распив
# 24. рефилл - флакон с оригинальной ароматической композицией в более простой упаковке, чаще всего без распылителя.
# 25. нос
# 26. аромат
# 27. парфюмер
# 28. запах
# 30. благовоние
# 31. масло
# 32. женщина
